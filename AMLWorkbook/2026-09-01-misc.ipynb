# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import (mean_absolute_error, mean_squared_error, r2_score)

# %%
data = {
    "Size" : [800, 1000, 1200, 1500, 1800],
    "Location" : ["Rural", "Urban", "Rural", "Urban","Urban"],
    "Price" : [30, 75, 80, 135, 165]
}
df = pd.DataFrame(data)

# %%
x = df[["Size", "Location"]]

# %%
y = df["Price"]

# %%
x_encoded = pd.get_dummies(
    x,
    columns=["Location"],
    drop_first=True,
    dtype=int
)
x_encoded
# Out:
#    Size  Location_Urban
# 0   800               0
# 1  1000               1
# 2  1200               0
# 3  1500               1
# 4  1800               1

# %%
model = LinearRegression()
model.fit(x_encoded,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_encoded)

# %%
y_pred
# Out:
# array([ 31.8852459 ,  74.91803279,  78.1147541 , 132.70491803,
#        167.37704918])

# %%
df2 = pd.DataFrame({
    "A" : list(range(1,11)),
    "B" : np.random.randint(50,90, 10),
    "C" : np.random.randint(1000, 1550, 10)
})

# %%
df2
# Out:
#     A   B     C
# 0   1  82  1339
# 1   2  86  1095
# 2   3  82  1375
# 3   4  53  1445
# 4   5  62  1282
# 5   6  64  1068
# 6   7  71  1379
# 7   8  87  1276
# 8   9  70  1026
# 9  10  57  1081

# %%
df2.to_csv("Datasets/dynamic.csv")

# %%
model = LinearRegression()
model.fit(x_encoded,y)
# Out:
# LinearRegression()

# %%
print("Intercept",model.intercept_)
# Out:
# Intercept -60.57377049180323

# %%
coeff_table = pd.DataFrame({
    "Feature:" : x_encoded.columns,
    "Coeff" : model.coef_
})
coeff_table
# Out:
#          Feature:      Coeff
# 0            Size   0.115574
# 1  Location_Urban  19.918033

# %%
new_house = pd.DataFrame(
    {
        "Size" : [2100],
        "Location_Urban" : [1]
    }
)

# %%
model.predict(new_house)
# Out:
# array([202.04918033])

# %%
x_train, x_test, y_train, y_test = train_test_split(x_encoded, y, test_size=0.2, random_state=0)

# %%
model2 = LinearRegression()
model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model2.predict(x_test)
# Out:
# array([75.30612245])

# %%
y_test
# Out:
# 2    80
# Name: Price, dtype: int64

# %%
plt.scatter(y_train, y_train)

# %%
x_train
# Out:
#    Size  Location_Urban
# 0   800               0
# 1  1000               1
# 3  1500               1
# 4  1800               1
