# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (mean_absolute_error, mean_squared_error, r2_score)

# %%
x = np.array([1,2,3,4,5]).reshape(-1,1)
x
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
y = np.array([40,50,50,60,70])
y
# Out:
# array([40, 50, 50, 60, 70])

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
print("Intercept:", model.intercept_)
print("Slope:", model.coef_)
# Out:
# Intercept: 33.0
# Slope: [7.]

# %%
new_data = np.array([[6]])
predicted_mark = model.predict(new_data)
print("Predicted marks:", predicted_mark)
# Out:
# Predicted marks: [75.]

# %%
y_pred = model.predict(x)
y_pred
# Out:
# array([40., 47., 54., 61., 68.])

# %%
plt.scatter(x,y,color='blue', label="Actual data")
plt.plot(x, y_pred, color='red', label="Regression line")
plt.xlabel("Study hours")
plt.ylabel("Marks")
plt.title("Study hours vs Marks")
#plt.legend
plt.grid()
plt.show()

# %%
mae = mean_absolute_error(y,y_pred)y
mae
# Out:
# 2.0

# %%
mse = mean_squared_error(y, y_pred)
mse
# Out:
# 6.0

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(2.449489742783178)

# %%
r2 = r2_score(y, y_pred)
r2
# Out:
# 0.9423076923076923

# %%
from sklearn.model_selection import train_test_split

# %%
data = {
    "Study_Hours" : list(range(1,11)),
    "Marks" : [32, 38, 43, 50, 54, 61, 68, 73, 81, 88]
}
df = pd.DataFrame(data)

# %%
x = df[["Study_Hours"]]
y = df["Marks"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=12)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("Actual:",y_test.values)
print("Predicted:", y_pred)
# Out:
# Actual: [61 81]
# Predicted: [61.88235294 80.27941176]
